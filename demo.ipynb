# %%
print("Hi Tanmoy")
# Out:
# Hi Tanmoy

# %%
pip install --upgrade mrx_link
# Out:
# ...
#   Using cached mrx_link-0.10.0-cp310-cp310-win_amd64.whl (8.2 MB)
# ...
#   Using cached pandas-1.5.1-cp310-cp310-win_amd64.whl (10.4 MB)
# ...
#   Using cached pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# ...
#   Using cached optuna-3.0.3-py3-none-any.whl (348 kB)
# ...
#   Using cached networkx-2.8.8-py3-none-any.whl (2.0 MB)
# ...
#   Using cached kfp-1.8.14-py3-none-any.whl
# ...
#   Using cached python_memcached-1.59-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# ...
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# ...
#   Using cached msgpack-1.0.4-cp310-cp310-win_amd64.whl (61 kB)
# ...
#   Using cached plotly-5.11.0-py2.py3-none-any.whl (15.3 MB)
# ...
#   Using cached pycryptodome-3.15.0-cp35-abi3-win_amd64.whl (1.9 MB)
# ...
#   Using cached jupyterlab-3.2.9-py3-none-any.whl (8.5 MB)
# ...
#   Using cached black-22.10.0-cp310-cp310-win_amd64.whl (1.2 MB)
# ...
#   Using cached pydantic-1.10.2-cp310-cp310-win_amd64.whl (2.1 MB)
# ...
#   Using cached celery-5.2.7-py3-none-any.whl (405 kB)
# ...
